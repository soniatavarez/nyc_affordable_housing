# %%
# !pip install psycopg2 sqlalchemy
# !pip install azure-storage-blob
# Out:
# Requirement already satisfied: psycopg2 in /Users/soniatavarez/anaconda3/lib/python3.11/site-packages (2.9.9)
# Requirement already satisfied: sqlalchemy in /Users/soniatavarez/anaconda3/lib/python3.11/site-packages (1.4.39)
# Requirement already satisfied: azure-storage-blob in /Users/soniatavarez/anaconda3/lib/python3.11/site-packages (12.19.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in /Users/soniatavarez/anaconda3/lib/python3.11/site-packages (from azure-storage-blob) (1.30.1)
# Requirement already satisfied: cryptography>=2.1.4 in /Users/soniatavarez/anaconda3/lib/python3.11/site-packages (from azure-storage-blob) (41.0.3)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/soniatavarez/anaconda3/lib/python3.11/site-packages (from azure-storage-blob) (4.11.0)
# Requirement already satisfied: isodate>=0.6.1 in /Users/soniatavarez/anaconda3/lib/python3.11/site-packages (from azure-storage-blob) (0.6.1)
# Requirement already satisfied: requests>=2.21.0 in /Users/soniatavarez/anaconda3/lib/python3.11/site-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /Users/soniatavarez/anaconda3/lib/python3.11/site-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /Users/soniatavarez/anaconda3/lib/python3.11/site-packages (from cryptography>=2.1.4->azure-storage-blob) (1.15.1)
# Requirement already satisfied: pycparser in /Users/soniatavarez/anaconda3/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/soniatavarez/anaconda3/lib/python3.11/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/soniatavarez/anaconda3/lib/python3.11/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/soniatavarez/anaconda3/lib/python3.11/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/soniatavarez/anaconda3/lib/python3.11/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2024.2.2)

# %%
import pandas as pd
import numpy as np
import json
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
from sqlalchemy import create_engine
from io import StringIO
from io import BytesIO

# %%
#config file/connection string setup 
config_file_path = 'config.json'

with open(config_file_path, 'r') as config_file:
    config = json.load(config_file)

# %%
CONNECTION_STRING_AZURE_STORAGE = config["connectionString"]
CONTAINER_AZURE='affordablehousing'

blob_service_client = BlobServiceClient.from_connection_string(CONNECTION_STRING_AZURE_STORAGE)
container_client = blob_service_client.get_container_client(CONTAINER_AZURE)

# %%
def azure_download_blob(connect_str, container_name, blob_name):
    blob_service_client = BlobServiceClient.from_connection_string(connect_str)
    blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
    download_stream = blob_client.download_blob()
    return download_stream.readall()

# %%
download_data=azure_download_blob(CONNECTION_STRING_AZURE_STORAGE, CONTAINER_AZURE, 'cleaned_affordablehousingdata.csv')

# %%
#converting csv download into df
download_data=pd.read_csv(BytesIO(download_data))
download_data
# Out:
#       project_id                    project_name  building_id house_number  \
# 0          44218  MEC E. 125TH ST. PARCEL B WEST       987329         2319
# 1          44225         Brook Avenue Apartments       927748          469
# 2          44225         Brook Avenue Apartments       955261          455
# 3          44230    Mermaid  / West. 16th Street       336111         2427
# 4          44230    Mermaid  / West. 16th Street       336151         3216
# ...          ...                             ...          ...          ...
# 4053       74669   731 LIBERTY AVENUE APARTMENTS       989464          735
# 4054       74671            729 731 EAST 32ND ST      1006551          729
# 4055       74671            729 731 EAST 32ND ST      1006620          731
# 4056       74673                   61 EAST 53 ST      1009851           61
# 4057       74824                2638 DECATUR AVE       991367         2638
#
#           street_name    borough  postcode   latitude  longitude  \
# 0            3 AVENUE  Manhattan   10035.0  40.804262 -73.935383
# 1     EAST 147 STREET      Bronx   10455.0  40.813854 -73.916400
# 2     EAST 147 STREET      Bronx   10455.0  40.813948 -73.916682
# 3      MERMAID AVENUE   Brooklyn   11224.0  40.575896 -73.991490
# 4      MERMAID AVENUE   Brooklyn   11224.0  40.575062 -73.998834
# ...               ...        ...       ...        ...        ...
# 4053   LIBERTY AVENUE   Brooklyn   11208.0  40.676466 -73.882637
# 4054   EAST 32 STREET   Brooklyn   11210.0  40.633299 -73.945770
# 4055   EAST 32 STREET   Brooklyn   11210.0  40.633267 -73.945766
# 4056   EAST 53 STREET   Brooklyn   11203.0  40.658937 -73.928211
# 4057   DECATUR AVENUE      Bronx   10458.0  40.863802 -73.889826
#
#      reporting_construction_type  ...  _3_br_units  _4_br_units  _5_br_units  \
# 0               New Construction  ...           15            0            0
# 1               New Construction  ...            0            0            0
# 2               New Construction  ...            1            0            0
# 3               New Construction  ...            2            0            0
# 4               New Construction  ...            2            0            0
# ...                          ...  ...          ...          ...          ...
# 4053            New Construction  ...            0            0            0
# 4054            New Construction  ...            0            0            0
# 4055            New Construction  ...            0            0            0
# 4056            New Construction  ...           10            0            0
# 4057            New Construction  ...            0            0            0
#
#       _6_br_units  counted_rental_units  counted_homeownership_units  \
# 0               0                   297                            0
# 1               0                    11                            0
# 2               0                    55                            0
# 3               0                     2                            1
# 4               0                     2                            1
# ...           ...                   ...                          ...
# 4053            0                     3                            0
# 4054            0                     2                            0
# 4055            0                     2                            0
# 4056            0                    20                            0
# 4057            0                    23                            0
#
#       all_counted_units  total_units  total_low_income_units  \
# 0                   297          404                     202
# 1                    11           11                      11
# 2                    55           55                      54
# 3                     3            3                       0
# 4                     3            3                       0
# ...                 ...          ...                     ...
# 4053                  3           10                       0
# 4054                  2            6                       0
# 4055                  2            6                       0
# 4056                 20           20                       0
# 4057                 23           24                       0
#
#       total_non_low_income_units
# 0                             93
# 1                              0
# 2                              0
# 3                              3
# 4                              3
# ...                          ...
# 4053                           3
# 4054                           2
# 4055                           2
# 4056                          20
# 4057                          23
#
# [4058 rows x 28 columns]

# %%
print(download_data.columns)
# Out:
# Index(['project_id', 'project_name', 'building_id', 'house_number',
#        'street_name', 'borough', 'postcode', 'latitude', 'longitude',
#        'reporting_construction_type', 'extremely_low_income_units',
#        'very_low_income_units', 'low_income_units', 'moderate_income_units',
#        'middle_income_units', 'studio_units', '_1_br_units', '_2_br_units',
#        '_3_br_units', '_4_br_units', '_5_br_units', '_6_br_units',
#        'counted_rental_units', 'counted_homeownership_units',
#        'all_counted_units', 'total_units', 'total_low_income_units',
#        'total_non_low_income_units'],
#       dtype='object')

# %%
df_ah=download_data.copy()

# %%
#allows to write over copied dataframe
pd.options.mode.copy_on_write = True

# %%
#creating borough dimension

borough=df_ah['borough'].unique()
dim_borough=pd.DataFrame(borough, columns=['borough_name'])
dim_borough['borough_id']=range(1, len(dim_borough) + 1)
dim_borough
# Out:
#     borough_name  borough_id
# 0      Manhattan           1
# 1          Bronx           2
# 2       Brooklyn           3
# 3         Queens           4
# 4  Staten Island           5

# %%
#creating project dimension
dim_project=df_ah[['project_id','project_name']]
dim_project=dim_project.drop_duplicates()
dim_project
# Out:
#       project_id                             project_name
# 0          44218           MEC E. 125TH ST. PARCEL B WEST
# 1          44225                  Brook Avenue Apartments
# 3          44230             Mermaid  / West. 16th Street
# 10         44239                  Home for Harlem Dowling
# 11         44256  WSFSSH. 145 WEST 108TH ST. VALLEY LODGE
# ...          ...                                      ...
# 4052       74668                      179 MARTENSE STREET
# 4053       74669            731 LIBERTY AVENUE APARTMENTS
# 4054       74671                     729 731 EAST 32ND ST
# 4056       74673                            61 EAST 53 ST
# 4057       74824                         2638 DECATUR AVE
#
# [1963 rows x 2 columns]

# %%
#creating building dimension 
dim_building=df_ah[['building_id','house_number','street_name','postcode', 'latitude', 'longitude',
       'reporting_construction_type']]
dim_building
# Out:
#       building_id house_number      street_name  postcode   latitude  \
# 0          987329         2319         3 AVENUE   10035.0  40.804262
# 1          927748          469  EAST 147 STREET   10455.0  40.813854
# 2          955261          455  EAST 147 STREET   10455.0  40.813948
# 3          336111         2427   MERMAID AVENUE   11224.0  40.575896
# 4          336151         3216   MERMAID AVENUE   11224.0  40.575062
# ...           ...          ...              ...       ...        ...
# 4053       989464          735   LIBERTY AVENUE   11208.0  40.676466
# 4054      1006551          729   EAST 32 STREET   11210.0  40.633299
# 4055      1006620          731   EAST 32 STREET   11210.0  40.633267
# 4056      1009851           61   EAST 53 STREET   11203.0  40.658937
# 4057       991367         2638   DECATUR AVENUE   10458.0  40.863802
#
#       longitude reporting_construction_type
# 0    -73.935383            New Construction
# 1    -73.916400            New Construction
# 2    -73.916682            New Construction
# 3    -73.991490            New Construction
# 4    -73.998834            New Construction
# ...         ...                         ...
# 4053 -73.882637            New Construction
# 4054 -73.945770            New Construction
# 4055 -73.945766            New Construction
# 4056 -73.928211            New Construction
# 4057 -73.889826            New Construction
#
# [4058 rows x 7 columns]

# %%
#creating fact table 
fact_table=df_ah[['very_low_income_units', 'low_income_units', 'moderate_income_units',
       'middle_income_units', 'studio_units', '_1_br_units', '_2_br_units',
       '_3_br_units', '_4_br_units', '_5_br_units', '_6_br_units',
       'counted_rental_units', 'counted_homeownership_units',
       'all_counted_units', 'total_units', 'total_low_income_units',
       'total_non_low_income_units','project_id','building_id','borough']]
fact_table['fact_id']=range(1, len(fact_table) + 1)
fact_table
# Out:
#       very_low_income_units  low_income_units  moderate_income_units  \
# 0                       101               101                      0
# 1                         0                11                      0
# 2                        14                40                      0
# 3                         0                 0                      3
# 4                         0                 0                      3
# ...                     ...               ...                    ...
# 4053                      0                 0                      0
# 4054                      0                 0                      0
# 4055                      0                 0                      0
# 4056                      0                 0                      0
# 4057                      0                 0                      0
#
#       middle_income_units  studio_units  _1_br_units  _2_br_units  \
# 0                      93            83           70          129
# 1                       0             0            1           10
# 2                       0             7           35           12
# 3                       0             0            0            1
# 4                       0             0            0            1
# ...                   ...           ...          ...          ...
# 4053                    3             3            0            0
# 4054                    2             0            2            0
# 4055                    2             0            2            0
# 4056                   20             5            5            0
# 4057                   23            16            5            2
#
#       _3_br_units  _4_br_units  _5_br_units  ...  counted_rental_units  \
# 0              15            0            0  ...                   297
# 1               0            0            0  ...                    11
# 2               1            0            0  ...                    55
# 3               2            0            0  ...                     2
# 4               2            0            0  ...                     2
# ...           ...          ...          ...  ...                   ...
# 4053            0            0            0  ...                     3
# 4054            0            0            0  ...                     2
# 4055            0            0            0  ...                     2
# 4056           10            0            0  ...                    20
# 4057            0            0            0  ...                    23
#
#       counted_homeownership_units  all_counted_units  total_units  \
# 0                               0                297          404
# 1                               0                 11           11
# 2                               0                 55           55
# 3                               1                  3            3
# 4                               1                  3            3
# ...                           ...                ...          ...
# 4053                            0                  3           10
# 4054                            0                  2            6
# 4055                            0                  2            6
# 4056                            0                 20           20
# 4057                            0                 23           24
#
#       total_low_income_units  total_non_low_income_units  project_id  \
# 0                        202                          93       44218
# 1                         11                           0       44225
# 2                         54                           0       44225
# 3                          0                           3       44230
# 4                          0                           3       44230
# ...                      ...                         ...         ...
# 4053                       0                           3       74669
# 4054                       0                           2       74671
# 4055                       0                           2       74671
# 4056                       0                          20       74673
# 4057                       0                          23       74824
#
#       building_id    borough fact_id
# 0          987329  Manhattan       1
# 1          927748      Bronx       2
# 2          955261      Bronx       3
# 3          336111   Brooklyn       4
# 4          336151   Brooklyn       5
# ...           ...        ...     ...
# 4053       989464   Brooklyn    4054
# 4054      1006551   Brooklyn    4055
# 4055      1006620   Brooklyn    4056
# 4056      1009851   Brooklyn    4057
# 4057       991367      Bronx    4058
#
# [4058 rows x 21 columns]

# %%
#mapping borough dimension to add borough id 
dict_borough=dict(zip(dim_borough['borough_name'],dim_borough['borough_id']))
print(dict_borough)
# Out:
# {'Manhattan': 1, 'Bronx': 2, 'Brooklyn': 3, 'Queens': 4, 'Staten Island': 5}

# %%
#mapping borough dimension to add borough id 
fact_table['borough_id']=fact_table['borough'].map(dict_borough)
fact_table
# Out:
#       very_low_income_units  low_income_units  moderate_income_units  \
# 0                       101               101                      0
# 1                         0                11                      0
# 2                        14                40                      0
# 3                         0                 0                      3
# 4                         0                 0                      3
# ...                     ...               ...                    ...
# 4053                      0                 0                      0
# 4054                      0                 0                      0
# 4055                      0                 0                      0
# 4056                      0                 0                      0
# 4057                      0                 0                      0
#
#       middle_income_units  studio_units  _1_br_units  _2_br_units  \
# 0                      93            83           70          129
# 1                       0             0            1           10
# 2                       0             7           35           12
# 3                       0             0            0            1
# 4                       0             0            0            1
# ...                   ...           ...          ...          ...
# 4053                    3             3            0            0
# 4054                    2             0            2            0
# 4055                    2             0            2            0
# 4056                   20             5            5            0
# 4057                   23            16            5            2
#
#       _3_br_units  _4_br_units  _5_br_units  ...  counted_homeownership_units  \
# 0              15            0            0  ...                            0
# 1               0            0            0  ...                            0
# 2               1            0            0  ...                            0
# 3               2            0            0  ...                            1
# 4               2            0            0  ...                            1
# ...           ...          ...          ...  ...                          ...
# 4053            0            0            0  ...                            0
# 4054            0            0            0  ...                            0
# 4055            0            0            0  ...                            0
# 4056           10            0            0  ...                            0
# 4057            0            0            0  ...                            0
#
#       all_counted_units  total_units  total_low_income_units  \
# 0                   297          404                     202
# 1                    11           11                      11
# 2                    55           55                      54
# 3                     3            3                       0
# 4                     3            3                       0
# ...                 ...          ...                     ...
# 4053                  3           10                       0
# 4054                  2            6                       0
# 4055                  2            6                       0
# 4056                 20           20                       0
# 4057                 23           24                       0
#
#       total_non_low_income_units  project_id  building_id    borough  fact_id  \
# 0                             93       44218       987329  Manhattan        1
# 1                              0       44225       927748      Bronx        2
# 2                              0       44225       955261      Bronx        3
# 3                              3       44230       336111   Brooklyn        4
# 4                              3       44230       336151   Brooklyn        5
# ...                          ...         ...          ...        ...      ...
# 4053                           3       74669       989464   Brooklyn     4054
# 4054                           2       74671      1006551   Brooklyn     4055
# 4055                           2       74671      1006620   Brooklyn     4056
# 4056                          20       74673      1009851   Brooklyn     4057
# 4057                          23       74824       991367      Bronx     4058
#
#      borough_id
# 0             1
# 1             2
# 2             2
# 3             3
# 4             3
# ...         ...
# 4053          3
# 4054          3
# 4055          3
# 4056          3
# 4057          2
#
# [4058 rows x 22 columns]

# %%
#dropping borough column 
fact_table.drop(columns=['borough'], inplace=True)
fact_table
# Out:
#       very_low_income_units  low_income_units  moderate_income_units  \
# 0                       101               101                      0
# 1                         0                11                      0
# 2                        14                40                      0
# 3                         0                 0                      3
# 4                         0                 0                      3
# ...                     ...               ...                    ...
# 4053                      0                 0                      0
# 4054                      0                 0                      0
# 4055                      0                 0                      0
# 4056                      0                 0                      0
# 4057                      0                 0                      0
#
#       middle_income_units  studio_units  _1_br_units  _2_br_units  \
# 0                      93            83           70          129
# 1                       0             0            1           10
# 2                       0             7           35           12
# 3                       0             0            0            1
# 4                       0             0            0            1
# ...                   ...           ...          ...          ...
# 4053                    3             3            0            0
# 4054                    2             0            2            0
# 4055                    2             0            2            0
# 4056                   20             5            5            0
# 4057                   23            16            5            2
#
#       _3_br_units  _4_br_units  _5_br_units  ...  counted_rental_units  \
# 0              15            0            0  ...                   297
# 1               0            0            0  ...                    11
# 2               1            0            0  ...                    55
# 3               2            0            0  ...                     2
# 4               2            0            0  ...                     2
# ...           ...          ...          ...  ...                   ...
# 4053            0            0            0  ...                     3
# 4054            0            0            0  ...                     2
# 4055            0            0            0  ...                     2
# 4056           10            0            0  ...                    20
# 4057            0            0            0  ...                    23
#
#       counted_homeownership_units  all_counted_units  total_units  \
# 0                               0                297          404
# 1                               0                 11           11
# 2                               0                 55           55
# 3                               1                  3            3
# 4                               1                  3            3
# ...                           ...                ...          ...
# 4053                            0                  3           10
# 4054                            0                  2            6
# 4055                            0                  2            6
# 4056                            0                 20           20
# 4057                            0                 23           24
#
#       total_low_income_units  total_non_low_income_units  project_id  \
# 0                        202                          93       44218
# 1                         11                           0       44225
# 2                         54                           0       44225
# 3                          0                           3       44230
# 4                          0                           3       44230
# ...                      ...                         ...         ...
# 4053                       0                           3       74669
# 4054                       0                           2       74671
# 4055                       0                           2       74671
# 4056                       0                          20       74673
# 4057                       0                          23       74824
#
#       building_id  fact_id  borough_id
# 0          987329        1           1
# 1          927748        2           2
# 2          955261        3           2
# 3          336111        4           3
# 4          336151        5           3
# ...           ...      ...         ...
# 4053       989464     4054           3
# 4054      1006551     4055           3
# 4055      1006620     4056           3
# 4056      1009851     4057           3
# 4057       991367     4058           2
#
# [4058 rows x 21 columns]

# %%
#reorganizing columns in fact table
new_order=['fact_id','borough_id','project_id','building_id','total_low_income_units',
           'total_non_low_income_units','very_low_income_units', 'low_income_units', 
           'moderate_income_units','middle_income_units', 'studio_units', '_1_br_units', '_2_br_units',
           '_3_br_units', '_4_br_units', '_5_br_units', '_6_br_units',
           'counted_rental_units', 'counted_homeownership_units',
           'all_counted_units', 'total_units', 
       ]

fact_table=fact_table[new_order]
fact_table.head()
# Out:
#    fact_id  borough_id  project_id  building_id  total_low_income_units  \
# 0        1           1       44218       987329                     202
# 1        2           2       44225       927748                      11
# 2        3           2       44225       955261                      54
# 3        4           3       44230       336111                       0
# 4        5           3       44230       336151                       0
#
#    total_non_low_income_units  very_low_income_units  low_income_units  \
# 0                          93                    101               101
# 1                           0                      0                11
# 2                           0                     14                40
# 3                           3                      0                 0
# 4                           3                      0                 0
#
#    moderate_income_units  middle_income_units  ...  _1_br_units  _2_br_units  \
# 0                      0                   93  ...           70          129
# 1                      0                    0  ...            1           10
# 2                      0                    0  ...           35           12
# 3                      3                    0  ...            0            1
# 4                      3                    0  ...            0            1
#
#    _3_br_units  _4_br_units  _5_br_units  _6_br_units  counted_rental_units  \
# 0           15            0            0            0                   297
# 1            0            0            0            0                    11
# 2            1            0            0            0                    55
# 3            2            0            0            0                     2
# 4            2            0            0            0                     2
#
#    counted_homeownership_units  all_counted_units  total_units
# 0                            0                297          404
# 1                            0                 11           11
# 2                            0                 55           55
# 3                            1                  3            3
# 4                            1                  3            3
#
# [5 rows x 21 columns]
